# %%
import os
import pandas as pd
import requests
from PIL import Image
from io import BytesIO

# %%
response = requests.get("http://localhost:5000/static/FTLogo.png")

# %%
response.status_code
# Out:
# 200

# %%
Image.open(BytesIO(response.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=385x379 at 0x10B54C080>
